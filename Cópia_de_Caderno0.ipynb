# %%
'''Este caderno é um tutorial e compilado de conhecimentos básicos de Python'''
# Out:
# 'Este caderno é um tutorial e compilado de conhecimentos básicos de Python'

# %%
a=90+10

# %%
a
# Out:
# 100

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
print("olá mundo")
# Out:
# olá mundo

# %%
#Comentário
##Estou fazendo um tutorial
###Estou fazendo uma revisão

# %% [markdown]
# #Texto
# ##Texto
# ###Texto

# %% [markdown]
# Este caderno é um tutorial. Pra comentar várias linhas use aspas triplas simples '''
# pra comentar uma linha #
# pra escrever textos o '#' aumenta o tamanho, é um código de html, exemplo
# ''' #texto'''
# '''##texto'''
# #texto

# %% [markdown]
# A identação sofre efeitos de hierarquias.

# %% [markdown]
# Vamos falar das funções built-in.
# len()
# type()
# list()
# tuple()

# %%
# ?.np.random.random()
# Out:
# Object `.np.random.random()` not found.

# %%
import numpy

# %%
import cv2

# %%
import pandas

# %%
import math

# %%
from math import * # importa todas as funções do pacote

# %%
pip install graphic
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.2/57.2 kB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.8/327.8 kB 1.9 MB/s eta 0:00:00
# ...
#   Created wheel for graphic: filename=graphic-1.0.0a6-py2.py3-none-any.whl size=106042 sha256=1befb6b85ee98abded7ae550bc15ecebff89ce4559823d2b6b7e11e3ab584a62
#   Stored in directory: /root/.cache/pip/wheels/82/e7/ec/12112338aa1faaa25397839443a9d1af93625ebbf51b555157
# Successfully built graphic
# ...

# %%
# !pip install graphic

# %%
# !pip install pandas

# %% [markdown]
# #Qual a diferença do import e do install?
# ##O import coloca a biblioteca no computador/ambiente.
# ##O import traz a biblioteca para dentro do programa rodando.
# ##O instal compra o livro e guarda na estante; o import, abre o livro

# %%
x=2**3

# %%
y= 4%2

# %%
x,y
# Out:
# (8, 0)

# %%
x==y
# Out:
# False

# %%
x and y
# Out:
# 0

# %%
x != y
# Out:
# True
